# %%
from fp_gpu import hello
from pauli_matrices import sigX, sigY, sigZ

print(hello())
# Out:
# Hello from fp-gpu!

# %%
print(sigX() @ sigY())  # Task 2c)
# Out:
# [[0.+1.j 0.+0.j]
#  [0.+0.j 0.-1.j]]
